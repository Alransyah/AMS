# %% [markdown]
# ## Eksperimen dan Pengumpulan Dataset

# %% [markdown]
# ## Pemanggilan Library 1

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    
    # Autentikasi dan akses menggunakan keys
    auth = tweepy.OAuthHandler("5SciYdsih97OtDTKgF2uKHVYF", 
    "q7ZFbgh2lbvwYNWzrVRvJJVD2iIyG3eTJr6TVwlNFCskhtCLq1")
    auth.set_access_token("1267078093505564672-ZIhrpO4Zo3PI1BEYTqYqglJw0437Hw", 
    "okuvszLK4RStLBZbnwaDRFGqPdYEYrSitfFwRRVmAYoG6")
    
    # Kembalikan akses ke API
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# Membuat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %% [markdown]
# ## Ambil Tweet dari Username
# Username yang saya gunakan yakni @MataNajwa

# %%
tweets = extractor.user_timeline(screen_name="KemenkesRI", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 200.
#
# 100 tweet teratas:
#
# Apabila kamu setiap hari konsumsi :
#
# -Gula lebih dari 50 gram
# -Garam lebih dari 2.000 mg
# -Lemak lebih dari 67 gram… https://t.co/MvyOkwsA6g
#
# Update Cakupan Vaksinasi COVID-19 di Indonesia (2/10)
#
# #ayovaksin
# #SayaPilihSehat https://t.co/nbLTjuYyNl
#
# Duka cita mendalam atas kejadian yang menimpa pecinta sepak bola di Stadion Kanjuruhan, Malang 🥀
#
# Teriring doa terb… https://t.co/r3fB5hr0vP
#
# Update Situasi Terkini Perkembangan #COVID19 di Indonesia (2/10)
#
# #LawanCovid19 #jagajarak #dirumahaja… https://t.co/u4IFoi57DA
#
# Update Cakupan Vaksinasi COVID-19 di Indonesia (1/10)
#
# #ayovaksin
# #SayaPilihSehat https://t.co/ZcBTWUav9F
#
# #RilisSehat
#
# Wujud Nyata Transformasi Layanan Rujukan, RSUP Dr. M. Djamil Padang Diperluas @KemenkesRI… https://t.co/EGpuLnk6zL
#
# Dalam satu hari, berapa banyak garam yang kamu konsumsi #Healthies?
#
# Jika lebih dari 2000 mg natrium atau 1 sendok… https://t.co/GST1SApQwX
#
# Update Situasi Terkini Perkembangan #COVID19 di Indonesia (1/10)
#
# #LawanCovid19 #jagajarak #dirumahaja… https://t.co/LFJ2Z1Hi8n
#
# Selamat Hari Kesaktian Pancasila
#
# Pancasila memiliki nilai-nilai persatuan dan kemanusiaan yang menjadi semangat k… https://t.co/NIsiKTaNxQ
#
# #RilisSehat
#
# Kini Check In PeduliLindungi Bisa Lewat Website @KemenkesRI
#
# https://t.co/krfmq3jAtx https://t.co/dCp0oxVGEO
#
# Melalui presidensi #G20, Indonesia mendorong agar semangat filantropi perlu dijaga dan dirawat untuk menghadapi pan… https://t.co/u1nkVz6hag
#
# Tindakan sukarela ini terbukti mampu meningkatkan ketahanan masyarakat dalam menghadapi krisis baik ekonomi maupun kesehatan.
#
# Filantropi membantu dunia menghadapi pandemi
#
# Terbukti saat pandemi COVID-19, banyak aksi-aksi filantropi yang lahi… https://t.co/4n6xDRivhR
#
# #RilisSehat
#
# Indonesia Bersiap Menuju Endemi @KemenkesRI
#
# https://t.co/SmlDnZ3VRz https://t.co/v3EHxczJyn
#
# #RilisSehat
#
# Kasus Probable Hepatitis Akut Bertambah 3 Orang, Total Jadi 99 Kasus @KemenkesRI… https://t.co/egRH77BbZ8
#
# #RilisSehat
#
# Kasus Monkeypox Mulai Melandai @KemenkesRI
#
# https://t.co/qXERq0Qg7T https://t.co/EeG0jwxaqK
#
# #RilisSehat
#
# Stok Vaksin COVID-19 Tersedia 5 Juta Dosis @KemenkesRI
#
# https://t.co/g4WWj5X3yk https://t.co/VOVA1LVR75
#
# #RilisSehat
#
# Pentingnya Kekuatan Filantropi untuk Mengatasi Pandemi @KemenkesRI
#
# https://t.co/JHVCrI6Ye9 https://t.co/gLS1a77ON4
#
# Update Situasi Terkini Perkembangan #COVID19 di Indonesia (30/9)
#
# #LawanCovid19 #jagajarak #dirumahaja… https://t.co/IC7ayJ7v86
#
# Gampangkan?
#
# Mulai sekarang jangan simpan obat sembarangan lagi ya #Healthies.
#
# Karena bukan hanya dia yang butuh… https://t.co/ndpVJdf1ST
#
# Untuk lebih lengkapnya, kamu bisa cek di kemasannya, disana ada informasi lengkap cara menyimpan obat yang kamu gunakan.
#
# #Gemacermat
#
# Obat sirup bisa kamu simpan disuhu ruangan, jangan di lemari pendingin. Alih-alih biar awet, cara ini justru bisa m… https://t.co/eFo2rmkw3Y
#
# Meski sama-sama obat, namun cara menyimpannya berbeda, harus disesuaikan dengan jenisnya
#
# Meski terlihat sepele, ke… https://t.co/PhEuAHOuV5
#
# Hai #Healthies!
#
# Masih punya obat sisa dirumah? Bingung cara menyimpan obat yang benar?
#
# Nah, kali ini #Minkes mau… https://t.co/m462f0os1P
#
# Pernah ngak sih kalian tiba tiba ngerasa nyeri dada?
#
# Terus pas browsing hasilnya terindikasi sakit Jantung 😱
#
# Pa… https://t.co/90T6N2mX55
#
# Update Cakupan Vaksinasi COVID-19 di Indonesia (29/9)
#
# #ayovaksin
# #SayaPilihSehat https://t.co/mT5IAR9gdN
#
# #Healthies, sekarang tenaga kesehatan bisa melakukan pengkinian data secara mandiri lho
#
# Carnya mudah, cukup isi da… https://t.co/LvyTQ4xObj
#
# Selamat Hari Jantung Sedunia 🫀
#
# Kebiasaan baik yang kita lakukan setiap hari bisa membuat tubuh sehat terhindar dar… https://t.co/2ZHqk4qbAt
#
# Update Situasi Terkini Perkembangan #COVID19 di Indonesia (29/9)
#
# #LawanCovid19 #jagajarak #dirumahaja… https://t.co/JuOIKnDRah
#
# Ingat Ya, kunci agar terhindar dari penyakit jantung itu PATUH.
#
# Apabila muncul gejala yang mengarah ke penyakit J… https://t.co/MFI6VdNome
#
# Imbangi budaya hidup sehat dengan rutin periksa ke dokter setidaknya 6 bulan sekali. Pemeriksaan ini penting untuk… https://t.co/wxVg4ko8WK
#
# Yang setiap harinya mengonsumsi gula, garam dan lemak dalam jumlah banyak sebaiknya dikurangi, makan sayur &amp; buahny… https://t.co/zHipRewJZT
#
# Pola hidup yang kurang sehat diduga jadi penyebab utamanya. Seperti kurang gerak, tingkat stress tinggi, dan pola m… https://t.co/hOa1HCprxk
#
# Dalam beberapa dekade terakhir jumlah penderita dan jumlah kematian akibat penyakit kardiovaksukal terus meningkat.… https://t.co/TrKJcEqTA4
#
# Jantung Sehat Untuk Semua 🫀
#
# #Healthies, jantung adalah inti dari kesehatan dan kehidupanmu. Karenanya perlu kita j… https://t.co/oMLT1tLgzi
#
# #RilisSehat
#
# 250 Ribu Vaksin Meningitis Siap Awal Oktober @KemenkesRI
#
# https://t.co/eC92GyzOD0 https://t.co/kM7rBSV5DP
#
# Hai #Healthies,
#
# @KemenkesRI membuka kesempatan untuk para nakes melakukan pengkinian data secara mandiri di laman… https://t.co/cLpo8YuzXx
#
# #RilisSehat
#
# Stok Vaksin Meningitis bagi Jemaah Haji dan Umroh Diperbanyak @KemenkesRI
#
# https://t.co/H4gP3Toz7y https://t.co/RPkByO7CMU
#
# #Healthies, pernah ngak sih kalian dikasih obat antibiotik?
#
# Dan menurut kalian itu perlu di habisin atau engga? https://t.co/d2udGK4Ark
#
# #RilisSehat
#
# Penyakit Jantung Penyebab Utama Kematian, Kemenkes Perkuat Layanan Primer @KemenkesRI… https://t.co/Bf0DuCLx78
#
# #RilisSehat
#
# Kemenkes Luncurkan Portal Pengkinian Data Nakes Terintegrasi @KemenkesRI
#
# https://t.co/6I4ntGjxJd https://t.co/8osVlhP7q3
#
# Rakyat Merdeka Award 2022 untuk Indonesia Pulih dan Bangkit merupakan bentuk apresiasi atas hasil kerja keras, sumb… https://t.co/L7s2FDUTfm
#
# Menkes adalah satu dari 31 tokoh yg dianugerahi Rakyat Merdeka Award 2022
#
# Tokoh-tokoh tersebut berasal dr berbagai… https://t.co/t8LZfHmFXk
#
# Selamat kepada Pak @BudiGSadikin atas anugrah sebagai tokoh pemulihan krisis kesehatan dalam Rakyat Merdeka Awards… https://t.co/pGczsPhWwa
#
# Update Cakupan Vaksinasi COVID-19 di Indonesia (28/9)
#
# #ayovaksin
# #SayaPilihSehat https://t.co/J9ohVe0y1x
#
# #Healthies, setiap 10 menit, satu orang meninggal karena rabies di dunia
#
# Meski berakibat fatal, rabies bisa dicega… https://t.co/L7aASg7VTE
#
# Update Situasi Terkini Perkembangan #COVID19 di Indonesia (28/9)
#
# #LawanCovid19 #jagajarak #dirumahaja… https://t.co/oEH8w7bJf4
#
# Buat #Healthies yang punya pertanyaan seputar penyakit jantung, siapkan pertanyaanmu dari sekarang dengan cara repl… https://t.co/TwnXr3yvhn
#
# #Healthies, 1 dari 3 kematian di Indonesia disebabkan penyakit jantung. Penyebab &amp; gejalanya beragam. Ada yg terlih… https://t.co/kwrcWSw1Id
#
# Nah, itu dia bahaya kelebihan konsumsi gula, garam dan lemak.
#
# Mulai sekarang, yuk konsumsi GGL sesuai anjuran. Ing… https://t.co/tL47Kp7n8x
#
# Melalui Permenkes ini, konsumsi GGL diatur.
#
# Dianjurkan asupan gula per hari tidak lebih dari 4 sendok makan gula,… https://t.co/5kUBqX2QCs
#
# Pemerintah turut mengatur konsumsi GGL di masyarakat
#
# Salah satunya menerbitkan Permenkes No. 30 Tahun 2013 yang di… https://t.co/q2AyHCXt02
#
# Caranya gimana?
#
# Mulai dari diri sendiri dulu yuk.
#
# Budayakan gaya hidup sehat dengan kurangi konsumsi gula, gara… https://t.co/iCFVTFm7lH
#
# Angka kematian akibat PTM juga tinggi lho. Setiap tahunnya lebih dari 600.000 orang di Indonesia meninggal akibat P… https://t.co/sqeqpKGQMh
#
# Dalam 5 tahun terakhir, presentase PTM di Indonesia terus meningkat setiap tahunnya
#
# PTM termasuk dalam penyakit k… https://t.co/8FHaQgSPGV
#
# #Healthies, tahukah kamu kurangnya kontrol konsumsi gula, garam dan lemak berkontribusi nyata terhadap terjadinya P… https://t.co/7toaHjggnk
#
# Yuk dukung pemulihan kesehatan, ekonomi dan pariwisata nasional dengan menyegerakan vaksinasi primer maupun booster… https://t.co/pp7ZV34Ch9
#
# Program vaksinasi WNA diberikan secara gratis mulai bulan September 2022 di fasilitas pelayanan kesehatan atau pos… https://t.co/qOby5RKh2y
#
# Mendukung pemulihan ekonomi &amp; pariwisata nasional, layanan vaksinasi COVID-19 diperluas
#
# Kini Warga Negara Asing (W… https://t.co/8nxZjHpmek
#
# #RilisSehat
#
# Konsumsi Gula Berlebih, Waspadai Risikonya @KemenkesRI
#
# https://t.co/v7m0c6jytI https://t.co/e8if18Vb9K
#
# #RilisSehat
#
# Dukung Upaya Pemulihan ekonomi dan Pariwisata, Program Vaksinasi Diperluas Bagi WNA @KemenkesRI… https://t.co/QK5aS82z0J
#
# Yuk kita jaga kesehatan jantung kita. Saksikan #TalkshowExclusive mengenai "Jantung Sehat untuk Semua (Memperingati… https://t.co/Kh43nOqgRa
#
# Memiliki jantung yang sehat adalah impian semua manusia, karena jantung memegang peranan penting agar semua organ t… https://t.co/7klkNsE62i
#
# Update Situasi Terkini Perkembangan #COVID19 di Indonesia (26/9)
#
# #LawanCovid19 #jagajarak #dirumahaja… https://t.co/5y0Tnqt1Tu
#
# #RilisSehat
#
# 260 Ribu Unit VTM Untuk Pelacakan Kasus COVID-19 Lebih Efisien @KemenkesRI
#
# https://t.co/bzeDEZg7dB https://t.co/DyzQrrxavD
#
# Di tengah siang yang terik, sering minum air putih ya #Healthies. Jangan tunggu haus💧
#
# Penuhi kebutuhan cairanmu dg… https://t.co/7Q8phXPFmI
#
# Lengkapnya, cek tabel berikut untuk tahu anjuran konsumsi Gula, Garam dan Lemak (GGL) per hari
#
# #CegahPTM https://t.co/BWEjD2YYit
#
# Lemak sebuah kandungan yang ditakuti kaum hawa 🫣. Kenapa?
#
# Lemak bisa membuat berat badan naik yang bisa meningkat… https://t.co/JrGgYt2bjm
#
# Makanan tanpa garam, rasanya hambar banget
#
# Tapi, jika takaran garam dalam satu hari lebih dari 1 sendok teh, risi… https://t.co/NBlF9sx2Pn
#
# Kalau makan terlalu banyak gula bisa bikin kegemukan, obesitas, diabetes melitus dan penyakit tidak menular lainnya… https://t.co/Rpr4j6LNFE
#
# Siang #Healthies!
#
# Makan siang adalah saat yg paling ditunggu-tunggu. Setuju? 😁
#
# Eits, tapi #Healthies harus bija… https://t.co/YsFATNizrM
#
# Setiap yg berlebihan tidak baik termasuk konsumsi gula. Krn berisiko tinggi terkena diabetes
#
# Namun, tak bisa dipun… https://t.co/ONFFH6w0cG
#
# Selalu waspada ya #Healthies!
#
# Bila ada tanda dan gejala yang mengarah ke DBD segera konsultasikan ke pelayanan ke… https://t.co/UGE1RAVlBP
#
# Cara terbaik untuk mengatasi DBD adalah mencegah tergigit nyamuk penyebab demam berdarah.
#
# Jaga kebersihan lingkun… https://t.co/8Wfw3WsvNT
#
# #Healthies, Siklus penyakit demam berdarah dikenal dengan "siklus pelana kuda" yang terbagi dalam 3 fase.
#
# Seperti… https://t.co/2TFtL0XwR9
#
# Harapannya, pengembangan vaksin TBC dapat berjalan sesuai target yang telah ditentukan dan bisa segera digunakan ba… https://t.co/F5whqhGtJ6
#
# Tak hanya memperkuat komitmen eliminasi TBC global, dukungan ini juga penting untuk mewujudkan implementasi pilar p… https://t.co/qQMkN5siQm
#
# Saat ini, vaksin TBC terbaru telah dikembangkan oleh peneliti vaksin TBC dari Eropa, Afrika dan Asia Tenggara.
#
# Me… https://t.co/RdHckAUAZC
#
# #Healthies, Indonesia memiliki peran besar dalam mencapai target eliminasi TBC tahun 2030
#
# Salah satu dukungannya a… https://t.co/MppmLVkxgD
#
# Dalam pertemuan ini, Menkes @BudiGSadikin juga mengundang @BillGates melakukan kunjungan ke Indonesia untuk melihat… https://t.co/qwuWd4eaar
#
# Dalam transformasi layanan primer terutama transformasi teknologi informasi, aksi nyata yang saat ini dilakukan ada… https://t.co/xdPmhtzKQt
#
# #Healties, Bill Gates mendukung transformasi kesehatan yang saat ini sedang berlangsung di Indonesia.
#
# Dukungan yan… https://t.co/fMfR1ao6mP
#
# Apabila terasa demam, sebaiknya segera memeriksakan diri ke Puskesmas atau Rumah Sakit ya!
#
# Ayo Waspada DBD! 🦟
#
# #Healthies, juga perlu waspada dengan gejala awal DBD seperti :
#
# - Demam tinggi mendadak berlangsung sepanjang hari… https://t.co/lcbiKBLmST
#
# Plus nya dengan :
#
# - Memelihara ikan pemakan jentik
# - Menaburkan larvasida untuk tempat yang tidak mungkin dilakuka… https://t.co/o0iWIm15Jb
#
# Kita bisa mencegah DBD dengan gerakan Pemberantasan Sarang Nyamuk (PSN) 3M Plus.
#
# Masih ingat gerakan 3M Plus? 🤔… https://t.co/dnIO73caID
#
# Upaya penanganan harus terus kita lakukan sejak dini.
#
# Kuncinya dengan jaga kesehatan diri dan kebersihan lingkung… https://t.co/E26vc8O3cz
#
# Saat ini, kasus DBD dilaporkan terus bertambah. Secara nasional, jumlah kasus DBD sejak Januari 2022 sebanyak 87.50… https://t.co/ytImvq1QWu
#
# Kadang hujan turun membawa sejuta kenangan, tapi tak jarang hujan kerap menimbulkan penyakit 😱
#
# Tetap waspada saat… https://t.co/ZXMf0YtBAa
#
# #RilisSehat
#
# Indonesia Usulkan Ikut Uji Klinis Vaksin TBC @KemenkesRI
#
# https://t.co/NnQg3rWrlf https://t.co/bktShAZwFV
#
# #Healthies, dalam satu tahun berapa kali kamu melakukan cek kesehatan?
#
# Dan kenapa sih cek kesehatan itu penting?… https://t.co/88GwWVFGbO
#
# #RilisSehat
#
# Masuk Peralihan Musim, Kemenkes Minta Dinkes Waspadai Lonjakan DBD @KemenkesRI… https://t.co/4eWjd5F39m
#
# Hal ini untuk memastikan kesiapan sistem kesehatan global dalam menghadapi ancaman kesehatan saat ini dan di masa y… https://t.co/iUhFyDaHAr
#
# Indonesia melalui Presidensi G20 mendorong negara anggota G20 memperkuat arsitektur kesehatan global melalui pengua… https://t.co/4BmesbxNnj
#
# Karena perbedaan kapasitas dan akses terhadap VTD akan berdampak pada kapasitas respons terhadap masalah kesehatan… https://t.co/0r6z6B7C4U
#
# Di forum tersebut, Menkes menyampaikan bahwa setiap negara, terlepas dari status ekonomi dan geografisnya, harus me… https://t.co/NlAgRhDU7G
#
# #Healthies, Menteri Kesehatan RI, @BudiGSadikin hadir dalam World Economic Forum yang digelar di New York, Amerika… https://t.co/lKnWfFMaAo
#
# #RilisSehat
#
# Penguatan Industri Kesehatan Domestik Jadi Basis Arsitektur Kesehatan Global @KemenkesRI… https://t.co/0kmZSKBHt6
#
# Sinergi, kolaborasi dan komitmen seluruh negara di dunia diharapkan bisa memperkuat sistem kesehatan global saat in… https://t.co/z88Wg2wLOM
#
# Tak hanya Indonesia, 48 negara dan lebih dari 25 sektor swasta juga ikut berkontribusi dalam replenishment Global F… https://t.co/JSCxIyPMRt

# %% [markdown]
# ## Masukan ke dalam dataframes Pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0   Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1   Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2   Duka cita mendalam atas kejadian yang menimpa ...
# 3   Update Situasi Terkini Perkembangan #COVID19 d...
# 4   Update Cakupan Vaksinasi COVID-19 di Indonesia...
# ..                                                ...
# 95  Di forum tersebut, Menkes menyampaikan bahwa s...
# 96  #Healthies, Menteri Kesehatan RI, @BudiGSadiki...
# 97  #RilisSehat\n\nPenguatan Industri Kesehatan Do...
# 98  Sinergi, kolaborasi dan komitmen seluruh negar...
# 99  Tak hanya Indonesia, 48 negara dan lebih dari ...
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_kemenkesRI.csv')

# %% [markdown]
# ## Cleaning Word

# %% [markdown]
# ## Import Library untuk Cleaning Word

# %%
import pandas as pd
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_kemenkesRI.csv')

df.head()
# Out:
#    Unnamed: 0                                             Tweets
# 0           0  Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1           1  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2           2  Duka cita mendalam atas kejadian yang menimpa ...
# 3           3  Update Situasi Terkini Perkembangan #COVID19 d...
# 4           4  Update Cakupan Vaksinasi COVID-19 di Indonesia...

# %%
df
# Out:
#      Unnamed: 0                                             Tweets
# 0             0  Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1             1  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2             2  Duka cita mendalam atas kejadian yang menimpa ...
# 3             3  Update Situasi Terkini Perkembangan #COVID19 d...
# 4             4  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# ..          ...                                                ...
# 195         195  #RilisSehat\n\nSistem Surveilans Terintegrasi ...
# 196         196  #RilisSehat\n\nPemerintah Berikan Imunisasi PC...
# 197         197  #RilisSehat\n\nPuncak HKGN 2022, Indonesia Pec...
# 198         198  #RilisSehat\n\nIndonesia Siap Perkuat Kerjasam...
# 199         199  Update Situasi Terkini Perkembangan #COVID19 d...
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ## Preprocessing Dataset
#
# Pertama lakukan instalasi modul ekphrasis

# %%
# !pip install ekphrasis
# Out:
# Collecting ekphrasis
#   Downloading ekphrasis-0.5.4-py3-none-any.whl (83 kB)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
# Requirement already satisfied: ujson in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: matplotlib in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (3.5.1)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (0.4.4)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (4.64.0)
# Collecting termcolor
#   Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: numpy in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (1.21.5)
# Requirement already satisfied: nltk in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\acer\anaconda3\lib\site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\acer\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer\anaconda3\lib\site-packages (from nltk->ekphrasis) (2022.3.15)
# Requirement already satisfied: click in c:\users\acer\anaconda3\lib\site-packages (from nltk->ekphrasis) (8.0.4)
# Requirement already satisfied: joblib in c:\users\acer\anaconda3\lib\site-packages (from nltk->ekphrasis) (1.1.0)
# Installing collected packages: termcolor, ftfy, ekphrasis
# Successfully installed ekphrasis-0.5.4 ftfy-6.1.1 termcolor-2.0.1

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Word statistics files not found!
# Downloading... done!
# Unpacking... done!
# Reading twitter - 1grams ...
# generating cache file for faster loading...
# reading ngrams C:\Users\acer\.ekphrasis\stats\twitter\counts_1grams.txt
# Reading twitter - 2grams ...
# generating cache file for faster loading...
# reading ngrams C:\Users\acer\.ekphrasis\stats\twitter\counts_2grams.txt
# Reading twitter - 1grams ...
# C:\Users\acer\anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Mulai proses pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1           1  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2           2  Duka cita mendalam atas kejadian yang menimpa ...
# 3           3  Update Situasi Terkini Perkembangan #COVID19 d...
# 4           4  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 5           5  #RilisSehat\n\nWujud Nyata Transformasi Layana...
# 6           6  Dalam satu hari, berapa banyak garam yang kamu...
# 7           7  Update Situasi Terkini Perkembangan #COVID19 d...
# 8           8  Selamat Hari Kesaktian Pancasila \n\nPancasila...
# 9           9  #RilisSehat\n\nKini Check In PeduliLindungi Bi...
#
#                                               step01
# 0  apabila kamu setiap hari konsumsi gula lebih d...
# 1  update cakupan vaksinasi covid   di indonesia ...
# 2  duka cita mendalam atas kejadian yang menimpa ...
# 3  update situasi terkini perkembangan di indones...
# 4  update cakupan vaksinasi covid   di indonesia ...
# 5  wujud nyata transformasi layanan rujukan rsup ...
# 6  dalam satu hari berapa banyak garam yang kamu ...
# 7  update situasi terkini perkembangan di indones...
# 8  selamat hari kesaktian pancasila pancasila mem...
# 9  kini check in pedulilindungi bisa lewat websit...

# %% [markdown]
# ## Hapus Data Kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
#  2   step01      200 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 127 to 127
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1 non-null      int64
#  1   Tweets      1 non-null      object
#  2   step01      1 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 32.0+ bytes

# %%
df_hapus.head(10)
# Out:
#      Unnamed: 0                                             Tweets step01
# 127         127  #FightForWhatCounts\n#BetterTogether\n#EndTB\n...

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  199 non-null    float64
#  1   Tweets      199 non-null    object
#  2   step01      199 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 6.2+ KB

# %%
df_new
# Out:
#      Unnamed: 0                                             Tweets  \
# 0           0.0  Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1           1.0  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2           2.0  Duka cita mendalam atas kejadian yang menimpa ...
# 3           3.0  Update Situasi Terkini Perkembangan #COVID19 d...
# 4           4.0  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# ..          ...                                                ...
# 195       195.0  #RilisSehat\n\nSistem Surveilans Terintegrasi ...
# 196       196.0  #RilisSehat\n\nPemerintah Berikan Imunisasi PC...
# 197       197.0  #RilisSehat\n\nPuncak HKGN 2022, Indonesia Pec...
# 198       198.0  #RilisSehat\n\nIndonesia Siap Perkuat Kerjasam...
# 199       199.0  Update Situasi Terkini Perkembangan #COVID19 d...
#
#                                                 step01
# 0    apabila kamu setiap hari konsumsi gula lebih d...
# 1    update cakupan vaksinasi covid   di indonesia ...
# 2    duka cita mendalam atas kejadian yang menimpa ...
# 3    update situasi terkini perkembangan di indones...
# 4    update cakupan vaksinasi covid   di indonesia ...
# ..                                                 ...
# 195  sistem surveilans terintegrasi menjadi modal h...
# 196  pemerintah berikan imunisasi pcv bagi seluruh ...
# 197  puncak hkgn   indonesia pecahkan rekor gerakan...
# 198  indonesia siap perkuat kerjasama guna mewujudk...
# 199  update situasi terkini perkembangan di indones...
#
# [199 rows x 3 columns]

# %% [markdown]
# ## Normalisasi kata slang menjadi baku

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0         0.0  Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1         1.0  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2         2.0  Duka cita mendalam atas kejadian yang menimpa ...
# 3         3.0  Update Situasi Terkini Perkembangan #COVID19 d...
# 4         4.0  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 5         5.0  #RilisSehat\n\nWujud Nyata Transformasi Layana...
# 6         6.0  Dalam satu hari, berapa banyak garam yang kamu...
# 7         7.0  Update Situasi Terkini Perkembangan #COVID19 d...
# 8         8.0  Selamat Hari Kesaktian Pancasila \n\nPancasila...
# 9         9.0  #RilisSehat\n\nKini Check In PeduliLindungi Bi...
#
#                                               step01  \
# 0  apabila kamu setiap hari konsumsi gula lebih d...
# 1  update cakupan vaksinasi covid   di indonesia ...
# 2  duka cita mendalam atas kejadian yang menimpa ...
# 3  update situasi terkini perkembangan di indones...
# 4  update cakupan vaksinasi covid   di indonesia ...
# 5  wujud nyata transformasi layanan rujukan rsup ...
# 6  dalam satu hari berapa banyak garam yang kamu ...
# 7  update situasi terkini perkembangan di indones...
# 8  selamat hari kesaktian pancasila pancasila mem...
# 9  kini check in pedulilindungi bisa lewat websit...
#
#                                               tokens
# 0  [apabila, kamu, setiap, hari, konsumsi, gula, ...
# 1  [update, cakupan, vaksinasi, covid, di, indone...
# 2  [duka, cita, mendalam, atas, kejadian, yang, m...
# 3  [update, situasi, terkini, perkembangan, di, i...
# 4  [update, cakupan, vaksinasi, covid, di, indone...
# 5  [wujud, nyata, transformasi, layanan, rujukan,...
# 6  [dalam, satu, hari, berapa, banyak, garam, yan...
# 7  [update, situasi, terkini, perkembangan, di, i...
# 8  [selamat, hari, kesaktian, pancasila, pancasil...
# 9  [kini, check, in, pedulilindungi, bisa, lewat,...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0         0.0  Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1         1.0  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2         2.0  Duka cita mendalam atas kejadian yang menimpa ...
# 3         3.0  Update Situasi Terkini Perkembangan #COVID19 d...
# 4         4.0  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 5         5.0  #RilisSehat\n\nWujud Nyata Transformasi Layana...
# 6         6.0  Dalam satu hari, berapa banyak garam yang kamu...
# 7         7.0  Update Situasi Terkini Perkembangan #COVID19 d...
# 8         8.0  Selamat Hari Kesaktian Pancasila \n\nPancasila...
# 9         9.0  #RilisSehat\n\nKini Check In PeduliLindungi Bi...
#
#                                               step01  \
# 0  apabila kamu setiap hari konsumsi gula lebih d...
# 1  update cakupan vaksinasi covid   di indonesia ...
# 2  duka cita mendalam atas kejadian yang menimpa ...
# 3  update situasi terkini perkembangan di indones...
# 4  update cakupan vaksinasi covid   di indonesia ...
# 5  wujud nyata transformasi layanan rujukan rsup ...
# 6  dalam satu hari berapa banyak garam yang kamu ...
# 7  update situasi terkini perkembangan di indones...
# 8  selamat hari kesaktian pancasila pancasila mem...
# 9  kini check in pedulilindungi bisa lewat websit...
#
#                                               tokens  \
# 0  [apabila, kamu, setiap, hari, konsumsi, gula, ...
# 1  [update, cakupan, vaksinasi, covid, di, indone...
# 2  [duka, cita, mendalam, atas, kejadian, yang, m...
# 3  [update, situasi, terkini, perkembangan, di, i...
# 4  [update, cakupan, vaksinasi, covid, di, indone...
# 5  [wujud, nyata, transformasi, layanan, rujukan,...
# 6  [dalam, satu, hari, berapa, banyak, garam, yan...
# 7  [update, situasi, terkini, perkembangan, di, i...
# 8  [selamat, hari, kesaktian, pancasila, pancasil...
# 9  [kini, check, in, pedulilindungi, bisa, lewat,...
#
#                                         final_tokens  \
# 0  [apabila, kamu, setiap, hari, konsumsi, gula, ...
# 1  [update, cakupan, vaksinasi, covid, di, indone...
# 2  [duka, cita, mendalam, atas, kejadian, yang, m...
# 3  [update, situasi, terkini, perkembangan, di, i...
# 4  [update, cakupan, vaksinasi, covid, di, indone...
# 5  [wujud, nyata, transformasi, layanan, rujukan,...
# 6  [dalam, satu, hari, berapa, banyak, garam, yan...
# 7  [update, situasi, terkini, perkembangan, di, i...
# 8  [selamat, hari, kesaktian, pancasila, pancasil...
# 9  [kini, check, in, pedulilindungi, bisa, lewat,...
#
#                                               step02
# 0  apabila kamu setiap hari konsumsi gula lebih d...
# 1  update cakupan vaksinasi covid di indonesia co...
# 2  duka cita mendalam atas kejadian yang menimpa ...
# 3  update situasi terkini perkembangan di indones...
# 4  update cakupan vaksinasi covid di indonesia co...
# 5  wujud nyata transformasi layanan rujukan rsup ...
# 6  dalam satu hari berapa banyak garam yang kamu ...
# 7  update situasi terkini perkembangan di indones...
# 8  selamat hari kesaktian pancasila pancasila mem...
# 9  kini check in pedulilindungi bisa lewat websit...

# %% [markdown]
# ## Simpan clean dataset

# %%
df_new.to_csv('clean_dataset.csv',sep=";")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df_new.to_csv('clean_dataset.csv',sep=";")
#
# NameError: name 'df_new' is not defined

# %% [markdown]
# # Stemming menggunakan sastrawi

# %%
import pandas as pd

# %%
dataset = pd.read_csv('clean_dataset.csv', sep=';')

# %%
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0         0.0
# 1             1         1.0
# 2             2         2.0
# 3             3         3.0
# 4             4         4.0
#
#                                               Tweets  \
# 0  Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1  Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2  Duka cita mendalam atas kejadian yang menimpa ...
# 3  Update Situasi Terkini Perkembangan #COVID19 d...
# 4  Update Cakupan Vaksinasi COVID-19 di Indonesia...
#
#                                               step01  \
# 0  apabila kamu setiap hari konsumsi gula lebih d...
# 1  update cakupan vaksinasi covid   di indonesia ...
# 2  duka cita mendalam atas kejadian yang menimpa ...
# 3  update situasi terkini perkembangan di indones...
# 4  update cakupan vaksinasi covid   di indonesia ...
#
#                                               tokens  \
# 0  ['apabila', 'kamu', 'setiap', 'hari', 'konsums...
# 1  ['update', 'cakupan', 'vaksinasi', 'covid', 'd...
# 2  ['duka', 'cita', 'mendalam', 'atas', 'kejadian...
# 3  ['update', 'situasi', 'terkini', 'perkembangan...
# 4  ['update', 'cakupan', 'vaksinasi', 'covid', 'd...
#
#                                         final_tokens  \
# 0  ['apabila', 'kamu', 'setiap', 'hari', 'konsums...
# 1  ['update', 'cakupan', 'vaksinasi', 'covid', 'd...
# 2  ['duka', 'cita', 'mendalam', 'atas', 'kejadian...
# 3  ['update', 'situasi', 'terkini', 'perkembangan...
# 4  ['update', 'cakupan', 'vaksinasi', 'covid', 'd...
#
#                                               step02
# 0  apabila kamu setiap hari konsumsi gula lebih d...
# 1  update cakupan vaksinasi covid di indonesia co...
# 2  duka cita mendalam atas kejadian yang menimpa ...
# 3  update situasi terkini perkembangan di indones...
# 4  update cakupan vaksinasi covid di indonesia co...

# %%
# !pip install sastrawi
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
 
factory = StopWordRemoverFactory()

more_stopword = ['sih', 'nya','rt','loh','lah', 'dd', 'mah', 'nye', 'eh', 'ehh', 'ah', 'yang','yg']
 
# Tambahkan Stopword Baru
data = factory.get_stop_words()+more_stopword

stopwords_sastrawi = factory.create_stop_word_remover()

dictionary = ArrayDictionary(data)
str_stopwords = StopWordRemover(dictionary)

# %%
dataset['finalText_str'] = dataset['step02'].apply(str)

# %%
i=0
final_string = []
s = ""
for sentence in dataset["finalText_str"].values:
    filteredSentence = []
    EachReviewText = ""
    st = str_stopwords.remove(sentence)
    s = (stemmer.stem(st))
    filteredSentence.append(s)
    
    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
dataset.loc[:, ('ProcessedText')] = final_string

# %%
dataset
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0         0.0
# 1               1         1.0
# 2               2         2.0
# 3               3         3.0
# 4               4         4.0
# ..            ...         ...
# 194           195       195.0
# 195           196       196.0
# 196           197       197.0
# 197           198       198.0
# 198           199       199.0
#
#                                                 Tweets  \
# 0    Apabila kamu setiap hari konsumsi : \n\n-Gula ...
# 1    Update Cakupan Vaksinasi COVID-19 di Indonesia...
# 2    Duka cita mendalam atas kejadian yang menimpa ...
# 3    Update Situasi Terkini Perkembangan #COVID19 d...
# 4    Update Cakupan Vaksinasi COVID-19 di Indonesia...
# ..                                                 ...
# 194  #RilisSehat\n\nSistem Surveilans Terintegrasi ...
# 195  #RilisSehat\n\nPemerintah Berikan Imunisasi PC...
# 196  #RilisSehat\n\nPuncak HKGN 2022, Indonesia Pec...
# 197  #RilisSehat\n\nIndonesia Siap Perkuat Kerjasam...
# 198  Update Situasi Terkini Perkembangan #COVID19 d...
#
#                                                 step01  \
# 0    apabila kamu setiap hari konsumsi gula lebih d...
# 1    update cakupan vaksinasi covid   di indonesia ...
# 2    duka cita mendalam atas kejadian yang menimpa ...
# 3    update situasi terkini perkembangan di indones...
# 4    update cakupan vaksinasi covid   di indonesia ...
# ..                                                 ...
# 194  sistem surveilans terintegrasi menjadi modal h...
# 195  pemerintah berikan imunisasi pcv bagi seluruh ...
# 196  puncak hkgn   indonesia pecahkan rekor gerakan...
# 197  indonesia siap perkuat kerjasama guna mewujudk...
# 198  update situasi terkini perkembangan di indones...
#
#                                                 tokens  \
# 0    ['apabila', 'kamu', 'setiap', 'hari', 'konsums...
# 1    ['update', 'cakupan', 'vaksinasi', 'covid', 'd...
# 2    ['duka', 'cita', 'mendalam', 'atas', 'kejadian...
# 3    ['update', 'situasi', 'terkini', 'perkembangan...
# 4    ['update', 'cakupan', 'vaksinasi', 'covid', 'd...
# ..                                                 ...
# 194  ['sistem', 'surveilans', 'terintegrasi', 'menj...
# 195  ['pemerintah', 'berikan', 'imunisasi', 'pcv', ...
# 196  ['puncak', 'hkgn', 'indonesia', 'pecahkan', 'r...
# 197  ['indonesia', 'siap', 'perkuat', 'kerjasama', ...
# 198  ['update', 'situasi', 'terkini', 'perkembangan...
#
#                                           final_tokens  \
# 0    ['apabila', 'kamu', 'setiap', 'hari', 'konsums...
# 1    ['update', 'cakupan', 'vaksinasi', 'covid', 'd...
# 2    ['duka', 'cita', 'mendalam', 'atas', 'kejadian...
# 3    ['update', 'situasi', 'terkini', 'perkembangan...
# 4    ['update', 'cakupan', 'vaksinasi', 'covid', 'd...
# ..                                                 ...
# 194  ['sistem', 'surveilans', 'terintegrasi', 'menj...
# 195  ['pemerintah', 'berikan', 'imunisasi', 'pcv', ...
# 196  ['puncak', 'hkgn', 'indonesia', 'pecahkan', 'r...
# 197  ['indonesia', 'siap', 'perkuat', 'kerjasama', ...
# 198  ['update', 'situasi', 'terkini', 'perkembangan...
#
#                                                 step02  \
# 0    apabila kamu setiap hari konsumsi gula lebih d...
# 1    update cakupan vaksinasi covid di indonesia co...
# 2    duka cita mendalam atas kejadian yang menimpa ...
# 3    update situasi terkini perkembangan di indones...
# 4    update cakupan vaksinasi covid di indonesia co...
# ..                                                 ...
# 194  sistem surveilans terintegrasi menjadi modal h...
# 195  pemerintah berikan imunisasi pcv bagi seluruh ...
# 196  puncak hkgn indonesia pecahkan rekor gerakan s...
# 197  indonesia siap perkuat kerjasama guna mewujudk...
# 198  update situasi terkini perkembangan di indones...
#
#                                          finalText_str  \
# 0    apabila kamu setiap hari konsumsi gula lebih d...
# 1    update cakupan vaksinasi covid di indonesia co...
# 2    duka cita mendalam atas kejadian yang menimpa ...
# 3    update situasi terkini perkembangan di indones...
# 4    update cakupan vaksinasi covid di indonesia co...
# ..                                                 ...
# 194  sistem surveilans terintegrasi menjadi modal h...
# 195  pemerintah berikan imunisasi pcv bagi seluruh ...
# 196  puncak hkgn indonesia pecahkan rekor gerakan s...
# 197  indonesia siap perkuat kerjasama guna mewujudk...
# 198  update situasi terkini perkembangan di indones...
#
#                                          ProcessedText
# 0    apabila kamu hari konsumsi gula lebih gram gar...
# 1    update cakup vaksinasi covid indonesia conbltj...
# 2    duka cita dalam atas jadi timpa cinta sepak bo...
# 3      update situasi kini kembang indonesia couifoida
# 4    update cakup vaksinasi covid indonesia cozcbtw...
# ..                                                 ...
# 194  sistem surveilans integrasi jadi modal hadap p...
# 195  perintah ikan imunisasi pcv seluruh anak indon...
# 196  puncak hkgn indonesia pecah rekor gera sikat g...
# 197  indonesia siap kuat kerjasama wujud transforma...
# 198     update situasi kini kembang indonesia corbgzgi
#
# [199 rows x 9 columns]

# %%
dataset.to_csv('clean_dataset_stem.csv',sep=';')
